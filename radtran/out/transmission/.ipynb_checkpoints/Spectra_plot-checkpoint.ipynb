# %%
import numpy as np
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import pylab

# %%
#Compare results for different concentrations

# %%
x1, y1 = np.loadtxt('Earth_midlatsummer_H2O_CO2_00010-10000_m09991_CH4.txt', delimiter=' ',unpack=True)
x2, y2 = np.loadtxt('Earth_midlatsummer_H2O_CO2_00010-10000_m09991_CH4_10+1.txt', delimiter=' ',unpack=True)
x5, y5 = np.loadtxt('Earth_midlatsummer_H2O_CO2_00010-10000_m09991_CH4_10+5.txt', delimiter=' ',unpack=True)
x8, y8 = np.loadtxt('Earth_midlatsummer_H2O_CO2_00010-10000_m09991_CH4_10+8.txt', delimiter=' ',unpack=True)
x12, y12 = np.loadtxt('Earth_midlatsummer_H2O_CO2_00010-10000_m09991_CH4_10+12.txt', delimiter=' ',unpack=True)



plt.plot(x1,y1,'b',markersize=0)
plt.plot(x2,y2,'r',markersize=0)
plt.plot(x5,y5,'k',markersize=0)
plt.plot(x8,y8,'g',markersize=0)
plt.plot(x12,y12,'y',markersize=0)
#plt.xlabel('')
#plt.ylabel('')
#plt.title('')
#plt.savefig('Spectra CO2/H2O/CH4')
plt.show()
